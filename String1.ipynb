# %%
a=123

# %%
type(a)
# Out:
# int

# %%
a=str(123)

# %%
type(a)
# Out:
# str

# %%
a='123'

# %%
type(a)
# Out:
# str

# %%
a="125"

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print ("Hello pythn")
# Out:
# Hello pythn
