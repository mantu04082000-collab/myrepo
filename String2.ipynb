# %%
m= "Mantu"

# %%
type(m)
# Out:
# str

# %%
m[0]
# Out:
# 'M'

# %%
m[1]
# Out:
# 'a'

# %%
m[2]
# Out:
# 'n'

# %%
m[3]
# Out:
# 't'

# %%
m[4]
# Out:
# 'u'

# %%
m[-1]
# Out:
# 'u'

# %%
m[-2]
# Out:
# 't'

# %%
m[-3]
# Out:
# 'n'

# %%
m[-4]
# Out:
# 'a'

# %%
m[-5]
# Out:
# 'M'

# %%
a= "My name is mantu"

# %%
a[-1]
# Out:
# 'u'

# %%
a[-2]
# Out:
# 't'

# %%
a
# Out:
# 'My name is mantu'

# %%
a[0:10]
# Out:
# 'My name is'

# %%
b ="Ineuron"

# %%
b[0:3]
# Out:
# 'Ine'

# %%
b[0:300]
# Out:
# 'Ineuron'

# %%
b[5]
# Out:
# 'o'

# %%
b[-1:-5]
# Out:
# ''

# %%
b[0:4]
# Out:
# 'Ineu'

# %%
a= "kumar"

# %%
a[0:3]
# Out:
# 'kum'

# %%
a[0:300:1]
# Out:
# 'kumar'

# %%
a[0:300:2]
# Out:
# 'kmr'

# %%
a[0:300:3]
# Out:
# 'ka'

# %%
a[0:100:-1]
# Out:
# ''

# %%
a[-1:-4]
# Out:
# ''

# %%
a[0:-10:-1]
# Out:
# 'k'

# %%
a[-1:-4:-1]
# Out:
# 'ram'

# %%
a
# Out:
# 'kumar'

# %%
a[::]
# Out:
# 'kumar'

# %%
a[:8]
# Out:
# 'kumar'

# %%
a[:-2]
# Out:
# 'kum'

# %%
a[-2:]
# Out:
# 'ar'
