# %%
t = (1,2,3,4,5)

# %%
type(t)
# Out:
# tuple

# %%
t1 = ("Mantu", 345, (45+78j), 546.56, True)

# %%
l = ["Mantu", 345, (45+78j), 546.56, True]

# %%
type(t1)
# Out:
# tuple

# %%
type(l)
# Out:
# list

# %%
t2 = ()

# %%
type(t2)
# Out:
# tuple

# %%
l1 = []

# %%
type(l1)
# Out:
# list

# %%
t1
# Out:
# ('Mantu', 345, (45+78j), 546.56)

# %%
l
# Out:
# ['Mantu', 345, (45+78j), 546.56, True]

# %%
k[0:2]
# Out:
# ['Mantu', 345]

# %%
t1[0:2]
# Out:
# ('Mantu', 345)

# %%
t1[::-1]
# Out:
# (True, 546.56, (45+78j), 345, 'Mantu')

# %%
t1[-1]
# Out:
# True

# %%
t1
# Out:
# ('Mantu', 345, (45+78j), 546.56, True)

# %%
t1[0::2]
# Out:
# ('Mantu', (45+78j), True)

# %%
l
# Out:
# ['Mantu', 345, (45+78j), 546.56, True]

# %%
l1 = [4,5,6,7]

# %%
l[0] = "kumar"

# %%
l
# Out:
# ['kumar', 345, (45+78j), 546.56, True]

# %%
t1
# Out:
# ('Mantu', 345, (45+78j), 546.56, True)

# %%
t1[0]
# Out:
# 'Mantu'

# %%
 s = "mantu"

# %%
s[0]
# Out:
# 'm'

# %%
t2 = (34,56,56,5,656)

# %%
t1+t2
# Out:
# ('Mantu', 345, (45+78j), 546.56, True, 34, 56, 56, 5, 656)

# %%
fruits = ["Apple", "Mango", "Banana"]

# %%
fruits.append("Orenge")

# %%
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana', 'Orenge']

# %%
l
# Out:
# ['kumar', 345, (45+78j), 546.56, True]

# %%
l1
# Out:
# [4, 5, 6, 7]

# %%
l+l1
# Out:
# ['kumar', 345, (45+78j), 546.56, True, 4, 5, 6, 7]

# %%
t1*2
# Out:
# ('Mantu', 345, (45+78j), 546.56, True, 'Mantu', 345, (45+78j), 546.56, True)

# %%
t1.count("Mantu")
# Out:
# 1

# %%
l
# Out:
# ['kumar', 345, (45+78j), 546.56, True]

# %%
t1.index("Mantu")
# Out:
# 0

# %%
t = (45,54,54,5, (4,5,6), ("mantu"))

# %%
t
# Out:
# (45, 54, 54, 5, (4, 5, 6), 'mantu')

# %%
  t1 = ([3,4,54,6] , ("mt" , 435,56) , "antu")

# %%
t1
# Out:
# ([3, 4, 54, 6], ('mt', 435, 56), 'antu')

# %%
t1[0][2] = "mantu"

# %%
 t1
# Out:
# ([3, 4, 'mantu', 6], ('mt', 435, 56), 'antu')

# %%
t1[0] = "ram"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 t1[0] = "ram"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1 = (53,54,45,4,5,54)

# %%
l = list(t1)

# %%
l
# Out:
# [53, 54, 45, 4, 5, 54]

# %%
tuple(l)
# Out:
# (53, 54, 45, 4, 5, 54)

# %%
l = [1,2,3,4,5,6,76,5,5,5,5,2,3,4,5,6,1,2,3]

# %%
set(l)
# Out:
# {1, 2, 3, 4, 5, 6, 76}

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s1 = {2,3,4}

# %%
type(s1)
# Out:
# set

# %%
s2 = {1,1,1,1,1,1,2,3,4,54,6,2,3,54}

# %%
s2
# Out:
# {1, 2, 3, 4, 6, 54}

# %%
S2[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 S2[0]
#
# NameError: name 'S2' is not defined

# %%
list(s2)
# Out:
# [1, 2, 3, 4, 6, 54]

# %%
s2
# Out:
# {1, 2, 3, 4, 6, 54}

# %%
s2.add(879756)

# %%
s2
# Out:
# {1, 2, 3, 4, 6, 54, 879756}

# %%
s2.add("mantu")

# %%
s2
# Out:
# {1, 2, 3, 4, 54, 6, 879756, 'mantu'}

# %%
s2.add([3,4,5,6])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s2.add([3,4,5,6])
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
{[3,4,5,6] ,3,4,5,6}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 {[3,4,5,6] ,3,4,5,6}
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
{(3,4,5,6) ,(3,4,5,6) ,3,4,5,3,5}
# Out:
# {(3, 4, 5, 6), 3, 4, 5}

# %%
s
# Out:
# {}

# %%
s2
# Out:
# {1, 2, 3, 4, 54, 6, 879756, 'mantu'}

# %%
s2.remove(54)

# %%
s2
# Out:
# {1, 2, 3, 4, 6, 879756, 'mantu'}

# %%
s2.discard(4)

# %%
s2
# Out:
# {1, 2, 3, 6, 879756, 'mantu'}

# %%
s2.remove(3)

# %%
s2
# Out:
# {1, 2, 6, 879756, 'mantu'}

# %%
s2.discard(54)

# %%
s2
# Out:
# {1, 2, 6, 879756, 'mantu'}

# %%
{"mantu" , "mantu"}
# Out:
# {'mantu'}

# %%
s  = {4,5,6,7,78 , 3,4,5,3,4,5 , "mantu" , "mantu"}

# %%
s
# Out:
# {3, 4, 5, 6, 7, 78, 'mantu'}

# %%
l = [3,4,5,6]

# %%
set(l)
# Out:
# {3, 4, 5, 6}

# %%
d = {3,4}

# %%
type(d)
# Out:
# set

# %%
d = {4:"mantu"}

# %%
d1 = {"key1" : 545 , "key2" : "mantu" , 45 : [3,4,5,6]}

# %%
l = [3,4,5,6,7]

# %%
d1
# Out:
# {'key1': 545, 'key2': 'mantu', 45: [3, 4, 5, 6]}

# %%
l[0]
# Out:
# 3

# %%
d1["key1"]
# Out:
# 545

# %%
d1[45]
# Out:
# [3, 4, 5, 6]

# %%
d3= {"+++":"venu"}

# %%
d = {
    "name": "mantu",
    "mo_no": 4866924146,
    "mail_id": "mantu@xyzgmail.com",
    "key1": [4,5,6,7],
    "key2": (3,4,5,6),
    "key3": {3,4,5},
    "key4": {1:5, 4:6}
}

# %%
d
# Out:
# {'name': 'mantu',
#  'mo_no': 4866924146,
#  'mail_id': 'mantu@xyzgmail.com',
#  'key1': [4, 5, 6, 7],
#  'key2': (3, 4, 5, 6),
#  'key3': {3, 4, 5},
#  'key4': {1: 5, 4: 6}}

# %%
type(d['key3'])
# Out:
# set

# %%
d['name']
# Out:
# 'mantu'

# %%
d['key4']
# Out:
# {1: 5, 4: 6}

# %%
type(d['name'])
# Out:
# str

# %%
type(d['key4'])
# Out:
# dict

# %%
t1 = (1,2,3,4,5)
type(t1)
# Out:
# tuple

# %%
t1 = (1)

# %%
type(t1)
# Out:
# int

# %%
i = 0
j = 3 
for i, j in range(i,j):
# Out:
#   Cell In[100], line 3
#     for i, j in range(i,j);
#                           ^
# SyntaxError: invalid syntax

# %%
i = 10
j = 6

# %%
i
# Out:
# 10

# %%
j
# Out:
# 6

# %%
i,j = 10,6

# %%
i
# Out:
# 10

# %%
j
# Out:
# 6

# %%
i = 4,5

# %%
i
# Out:
# (4, 5)

# %%
student={
"name": "mantu",
    "score":{
        "chem": 98,
        "phy": 97,
        "math": 95
    }
}

# %%
student ["score"]["math"]
# Out:
# 95
